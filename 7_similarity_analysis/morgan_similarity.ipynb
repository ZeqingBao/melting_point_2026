# %%
import pandas as pd

df_all_rfe = pd.read_parquet("../0_data/processed_data/data_with_selected_features_LGB_All_scaled.parquet")
df_all_rfe
# Out:
#                                                   SMILES      MP   Type  \
# 0      COc1ccc(cc1)C1(C)CCc2c(-c3c1cc(o3)C)c1c(o2)ccc...  170.00  Train
# 1      C[C@H]1[C@@H]2CC[C@@H]3[C@](C1=O)(C2)C(=O)OC[C...  296.85  Train
# 2                                     Cc1cc(Br)c(cc1Br)C   73.00  Train
# 3                                   OC(=O)c1ccc(c(c1)F)C  170.00  Train
# 4                                OC(=O)C1CC(=O)c2c1cccc2  116.00  Train
# ...                                                  ...     ...    ...
# 17215                   CN(CCNCc1cc(ccc1O)[N+](=O)[O-])C  158.50   Test
# 17216             C[Si](C#Cc1ccc(cc1)C#C[Si](C)(C)C)(C)C  120.00   Test
# 17217                 Brc1ccc(c(c1)C(F)(F)F)[N+](=O)[O-]   34.00   Test
# 17218                           OC(=O)C(C(=O)O)Cc1ccccc1  121.00   Test
# 17219                              OC(c1ccc(cc1)F)C(=O)O  136.00   Test
#
#       MP_label  RDKit_FpDensityMorgan3  RDKit_TPSA  RDKit_NumRotatableBonds  \
# ...

# %%
# Get all column names as a list
all_columns = df_all_rfe.columns.tolist()

print(f"Total columns: {len(all_columns)}")
print(all_columns)
# Out:
# Total columns: 87
# ...
